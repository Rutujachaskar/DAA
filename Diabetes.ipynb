# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.metrics import classification_report,precision_score,accuracy_score,recall_score,confusion_matrix,ConfusionMatrixDisplay

# %%
data=pd.read_csv("diabetes.csv")
data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
X=data.drop('Outcome',axis=1)

# %%
y=data['Outcome']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.20)

# %%
X_train.shape
y_train.shape
# Out:
# (614,)

# %%
from sklearn.neighbors import KNeighborsClassifier
neigh=KNeighborsClassifier(n_neighbors=2)
neigh.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=2)

# %%
y_pred=neigh.predict(X_test)

# %%
neigh.score(X_train,y_train)
neigh.score(X_test,y_test)
# Out:
# 0.7467532467532467

# %%
print("Classification Report")
classification_report(y_test,y_pred)
# Out:
# Classification Report
# '              precision    recall  f1-score   support\n\n           0       0.79      0.88      0.83       110\n           1       0.58      0.41      0.48        44\n\n    accuracy                           0.75       154\n   macro avg       0.68      0.65      0.66       154\nweighted avg       0.73      0.75      0.73       154\n'

# %%
print("Confusion Matrix")
cm=confusion_matrix(y_test,y_pred)
cm
# Out:
# Confusion Matrix
# array([[97, 13],
#        [26, 18]])

# %%
import matplotlib.pyplot as plt
print("Confusion Matrix Display")
model=ConfusionMatrixDisplay(confusion_matrix=cm)
model.plot()
plt.show()
# Out:
# Confusion Matrix Display

# %%
print("Accuracy Score")
accuracy_score(y_test,y_pred)
# Out:
# Accuracy Score
# 0.7467532467532467

# %%
print("Recall Score")
recall_score(y_test,y_pred)
# Out:
# Recall Score
# 0.4090909090909091

# %%
print("Precision Score")
precision_score(y_test,y_pred)
# Out:
# Precision Score
# 0.5806451612903226

# %%
from sklearn.svm import SVC
SVM=SVC(gamma='auto')
SVM.fit(X_train,y_train)
# Out:
# SVC(gamma='auto')

# %%
print("Confusion Matrix")
cm=confusion_matrix(y_test,y_pred)
# Out:
# Confusion Matrix

# %%
SVM.score(X_train,y_train)
SVM.score(X_test,y_test)
# Out:
# 0.7142857142857143

# %%
mat=ConfusionMatrixDisplay(confusion_matrix=cm)
mat.plot()
plt.show()
